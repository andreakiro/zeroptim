# %%
from zeroptim.dataset.vision import VisionDataset
from zeroptim.dataset.utils import visualize_samples
d = VisionDataset.make_loader('mnist-fashion')
visualize_samples(d, 5)
# Out:
# /Users/apinto/.virtualenvs/pytorch-mezo-pciu/lib/python3.11/site-packages/pydantic/_internal/_fields.py:149: UserWarning: Field "model_params" has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(

# %%
from zeroptim.configs.serialization import parse
from zeroptim.dataset.utils import visualize_samples
from zeroptim import DatasetFactory
config = parse("configs/mlp.yaml")
d = DatasetFactory.make_loader(config)
visualize_samples(d, 5)
